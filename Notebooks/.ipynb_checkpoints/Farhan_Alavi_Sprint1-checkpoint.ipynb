# %% [markdown]
# ## Capstone draft 1. Getting familiar with the data

# %% [markdown]
# ### Plan of attack
#
# 1. Read the file (Acquire data)
# 2. Take an initial look at the data (including the head, tail, info, etc.)
# 3. Wrangle, process, and clean the data
# 4. EDA - Exploratory Data Analysis

# %% [markdown]
# ### Table of Contents
# - [Importing and initial reading](#Part-1a)
# - [Shape and dictionary information](#Part-1b)
# - [Data cleaning](#Part-2)
# - [Obeservations](#Part-3)

# %% [markdown]
# ## Part 1a
# importing and initial reading of each individual CSV

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
mer = pd.read_csv('Merged.csv')
mer
# Out:
#           County  Year  Population   Males  Females  White Males  \
# 0      Alameda    2001     1468652  723957   744695       430526
# 1      Alameda    2002     1460438  720008   740430       426013
# 2      Alameda    2003     1451418  715373   736045       421147
# 3      Alameda    2004     1441496  710595   730901       416592
# 4      Alameda    2005     1435870  708070   727800       413816
# ...          ...   ...         ...     ...      ...          ...
# 62519     Yuba    2018       77557   39249    38308        30806
# 62520     Yuba    2019       78668   39819    38849        31245
# 62521     Yuba    2020       81994   42004    39990        32575
# 62522     Yuba    2021       83216   42550    40666        32760
# 62523     Yuba    2022       84310   43017    41293        32745
#
#        White Females  Black Males  Black Females  Native Males  ...  \
# 0             426851       101773         116649          5637  ...
# 1             422003        98418         113065          5651  ...
# 2             417397        95566         110066          5691  ...
# 3             412797        93024         107047          5729  ...
# 4             409781        90566         104032          5748  ...
# ...              ...          ...            ...           ...  ...
# 62519          30125         1861           1521          1050  ...
# 62520          30419         1909           1595          1029  ...
# 62521          31007         2083           1714          1162  ...
# 62522          31234         2200           1826          1200  ...
# 62523          31381         2292           1985          1205  ...
#
#        Hispanic-White Mixed Males  Hispanic-White Mixed Females  \
# 0                          137800                        125878
# 1                          139729                        127753
# 2                          140761                        128789
# 3                          141652                        130010
# 4                          143345                        131666
# ...                           ...                           ...
# 62519                       10162                          9668
# 62520                       10462                         10024
# 62521                       11102                         10410
# 62522                       11487                         10788
# 62523                       11981                         11247
#
#        Hispanic-Black Mixed Males  Hispanic-Black Mixed Females  \
# 0                            5423                          5630
# 1                            5400                          5632
# 2                            5389                          5664
# 3                            5360                          5661
# 4                            5386                          5651
# ...                           ...                           ...
# 62519                         486                           469
# 62520                         493                           481
# 62521                         574                           563
# 62522                         576                           586
# 62523                         617                           591
#
#        Hispanic-Native Mixed Males  Hispanic-Native Mixed Females  \
# 0                             4401                           4138
# 1                             4448                           4162
# 2                             4457                           4131
# 3                             4469                           4146
# 4                             4429                           4150
# ...                            ...                            ...
# 62519                          949                            982
# 62520                          951                            973
# 62521                         1035                           1006
# 62522                         1088                           1053
# 62523                         1149                           1070
#
#        Hispanic-Asian Mixed Males  Hispanic-Asian Mixed Females  \
# 0                            3883                          4150
# 1                            3955                          4210
# 2                            3984                          4186
# 3                            4017                          4238
# 4                            4109                          4305
# ...                           ...                           ...
# 62519                         399                           404
# 62520                         407                           405
# 62521                         479                           480
# 62522                         512                           509
# 62523                         558                           529
#
#        Hispanic-Hawaiian Mixed Males  Hispanic-Hawaiian Mixed Females
# 0                               1186                             1254
# 1                               1214                             1250
# 2                               1257                             1241
# 3                               1253                             1277
# 4                               1272                             1284
# ...                              ...                              ...
# 62519                            103                               88
# 62520                            117                              113
# 62521                            150                              134
# 62522                            158                              135
# 62523                            178                              141
#
# [62524 rows x 75 columns]

# %%
raw_inf = pd.read_csv('infectious1.csv')
raw_inf
# Out:
#                      Disease   County  Year     Sex  Cases  Population Rate
# 0               Anaplasmosis  Alameda  2001  Female      0      746596    -
# 1               Anaplasmosis  Alameda  2001    Male      0      718968    -
# 2               Anaplasmosis  Alameda  2001   Total      0     1465564    -
# 3               Anaplasmosis  Alameda  2002  Female      0      747987    -
# 4               Anaplasmosis  Alameda  2002    Male      0      720481    -
# ...                      ...      ...   ...     ...    ...         ...  ...
# 189916  Zika Virus Infection     Yuba  2021    Male      0       39302    -
# 189917  Zika Virus Infection     Yuba  2021   Total      0       82211    -
# 189918  Zika Virus Infection     Yuba  2022  Female      0       39108    -
# 189919  Zika Virus Infection     Yuba  2022    Male      0       39558    -
# 189920  Zika Virus Infection     Yuba  2022   Total      0       82533    -
#
# [189921 rows x 7 columns]

# %%
raw_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189921 entries, 0 to 189920
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Disease     189921 non-null  object
#  1   County      189921 non-null  object
#  2   Year        189921 non-null  int64
#  3   Sex         189921 non-null  object
#  4   Cases       189921 non-null  int64
#  5   Population  189921 non-null  int64
#  6   Rate        189921 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.1+ MB

# %% [markdown]
# ## Part 1b
# Shape and dictionary information of each CSV

# %%
raw_inf.shape
# Out:
# (189921, 7)

# %%
mer.shape
# Out:
# (62524, 75)

# %%
raw_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189921 entries, 0 to 189920
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Disease     189921 non-null  object
#  1   County      189921 non-null  object
#  2   Year        189921 non-null  int64
#  3   Sex         189921 non-null  object
#  4   Cases       189921 non-null  int64
#  5   Population  189921 non-null  int64
#  6   Rate        189921 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 10.1+ MB

# %% [markdown]
# | Column Name | Datatype |   |
# |-------------|----------|---|
# | Disease     | Object   |   |
# | County      | Object   |   |
# | Year        | int64    |   |
# | Sex         | Object   |   |
# | Cases       | int64    |   |
# | Population  | int64    |   |
# | Rate        | Object   |   |
# |             |          |   |
# |             |          |   |

# %%
mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62524 entries, 0 to 62523
# Data columns (total 75 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   County                                62524 non-null  object
#  1   Year                                  62524 non-null  int64
#  2   Population                            62524 non-null  int64
#  3   Males                                 62524 non-null  int64
#  4   Females                               62524 non-null  int64
#  5   White Males                           62524 non-null  int64
#  6   White Females                         62524 non-null  int64
#  7   Black Males                           62524 non-null  int64
#  8   Black Females                         62524 non-null  int64
#  9   Native Males                          62524 non-null  int64
#  10  Native Females                        62524 non-null  int64
#  11  Asian Males                           62524 non-null  int64
#  12  Asian Females                         62524 non-null  int64
#  13  Hawaiian Male                         62524 non-null  int64
#  14  Hawaiian Females                      62524 non-null  int64
#  15  Multi-Race Males                      62524 non-null  int64
#  16  Multi-Race Females                    62524 non-null  int64
#  17  White-Mixed Males                     62524 non-null  int64
#  18  White-Mixed Females                   62524 non-null  int64
#  19  Black-Mixed Males                     62524 non-null  int64
#  20  Black-Mixed Females                   62524 non-null  int64
#  21  Native-Mixed Males                    62524 non-null  int64
#  22  Native-Mixed Females                  62524 non-null  int64
#  23  Asian-Mixed Males                     62524 non-null  int64
#  24  Asian-Mixed Females                   62524 non-null  int64
#  25  Hawaiian-Mixed Males                  62524 non-null  int64
#  26  Hawaiian-Mixed Females                62524 non-null  int64
#  27  Not-Hispanic Males                    62524 non-null  int64
#  28  Not-Hispanic Females                  62524 non-null  int64
#  29  Not-Hispanic White Males              62524 non-null  int64
#  30  Not-Hispanic White Females            62524 non-null  int64
#  31  Not-Hispanic Black Males              62524 non-null  int64
#  32  Not-Hispanic Black Males.1            62524 non-null  int64
#  33  Not-Hispanic Native Male              62524 non-null  int64
#  34  Not-Hispanic Native Female            62524 non-null  int64
#  35  Not-Hispanic Asian Male               62524 non-null  int64
#  36  Not-Hispanic Asian Female             62524 non-null  int64
#  37  Not-Hispanic Hawaiian Male            62524 non-null  int64
#  38  Not-Hispanic Hawaiian Female          62524 non-null  int64
#  39  Not_Hispanic Mixed Males              62524 non-null  int64
#  40  Not_Hispanic Mixed Females            62524 non-null  int64
#  41   Not_Hispanic White-Mixed Males       62524 non-null  int64
#  42   Not_Hispanic White-Mixed Females     62524 non-null  int64
#  43   Not_Hispanic Black-Mixed Males       62524 non-null  int64
#  44   Not_Hispanic Black-Mixed Males.1     62524 non-null  int64
#  45   Not_Hispanic Native-Mixed Males      62524 non-null  int64
#  46   Not_Hispanic Native-Mixed Females    62524 non-null  int64
#  47   Not_Hispanic Asian-Mixed Males       62524 non-null  int64
#  48   Not_Hispanic Asian-Mixed Females     62524 non-null  int64
#  49   Not_Hispanic Hawaiian-Mixed Males    62524 non-null  int64
#  50   Not_Hispanic Hawaiian-Mixed Females  62524 non-null  int64
#  51  Hispanic Males                        62524 non-null  int64
#  52  Hispanic Females                      62524 non-null  int64
#  53  Hispanic-White Males                  62524 non-null  int64
#  54  Hispanic-White Females                62524 non-null  int64
#  55  Hispanic-Black Males                  62524 non-null  int64
#  56  Hispanic-Black Females                62524 non-null  int64
#  57  Hispanic-Native Males                 62524 non-null  int64
#  58  Hispanic-Native Females               62524 non-null  int64
#  59  Hispanic-Asian Males                  62524 non-null  int64
#  60  Hispanic-Asian Females                62524 non-null  int64
#  61  Hispanic-Hawaiian Males               62524 non-null  int64
#  62  Hispanic-Hawaiian Females             62524 non-null  int64
#  63  Hispanic-Mixed Males                  62524 non-null  int64
#  64  Hispanic-Mixed Females                62524 non-null  int64
#  65  Hispanic-White Mixed Males            62524 non-null  int64
#  66  Hispanic-White Mixed Females          62524 non-null  int64
#  67  Hispanic-Black Mixed Males            62524 non-null  int64
#  68  Hispanic-Black Mixed Females          62524 non-null  int64
#  69  Hispanic-Native Mixed Males           62524 non-null  int64
#  70  Hispanic-Native Mixed Females         62524 non-null  int64
#  71  Hispanic-Asian Mixed Males            62524 non-null  int64
#  72  Hispanic-Asian Mixed Females          62524 non-null  int64
#  73  Hispanic-Hawaiian Mixed Males         62524 non-null  int64
#  74  Hispanic-Hawaiian Mixed Females       62524 non-null  int64
# dtypes: int64(74), object(1)
# memory usage: 35.8+ MB

# %% [markdown]
# | Column Name                       | Data type |
# |-----------------------------------|-----------|
# | County                            | Object    |
# | Year                              | int       |
# | Population                        | int       |
# | Males                             | int       |
# | Females                           | int       |
# | White Males                       | int       |
# | White Females                     | int       |
# | Black Males                       | int       |
# | Black Females                     | int       |
# | Native Males                      | int       |
# | Native Females                    | int       |
# | Asian Males                       | int       |
# | Asian Females                     | int       |
# | Hawaiian Male                     | int       |
# | Hawaiian Females                  | int       |
# | Multi-Race Males                  | int       |
# | Multi-Race Females                | int       |
# | White-Mixed Males                 | int       |
# | White-Mixed Females               | int       |
# | Black-Mixed Males                 | int       |
# | Black-Mixed Females               | int       |
# | Native-Mixed Males                | int       |
# | Native-Mixed Females              | int       |
# | Asian-Mixed Males                 | int       |
# | Asian-Mixed Females               | int       |
# | Hawaiian-Mixed Males              | int       |
# | Hawaiian-Mixed Females            | int       |
# | Not-Hispanic Males                | int       |
# | Not-Hispanic Females              | int       |
# | Not-Hispanic White Males          | int       |
# | Not-Hispanic White Females        | int       |
# | Not-Hispanic Black Males          | int       |
# | Not-Hispanic Black Males.1        | int       |
# | Not-Hispanic Native Male          | int       |
# | Not-Hispanic Native Female        | int       |
# | Not-Hispanic Asian Male           | int       |
# | Not-Hispanic Asian Female         | int       |
# | Not-Hispanic Hawaiian Male        | int       |
# | Not-Hispanic Hawaiian Female      | int       |
# | Not_Hispanic Mixed Males          | int       |
# | Not_Hispanic Mixed Females        | int       |
# | Not_Hispanic White-Mixed Males    | int       |
# | Not_Hispanic White-Mixed Females  | int       |
# | Not_Hispanic Black-Mixed Males    | int       |
# | Not_Hispanic Black-Mixed Males.1  | int       |
# | Not_Hispanic Native-Mixed Males   | int       |
# | Not_Hispanic Native-Mixed Females | int       |
# | Not_Hispanic Asian-Mixed Males    | int       |
# | Not_Hispanic Asian-               | int       |

# %% [markdown]
# ## Part 2
# Data cleaning of each CSV

# %%
raw_inf.duplicated().sum()
# Out:
# 0

# %%
raw_inf.isna().sum()
# Out:
# Disease       0
# County        0
# Year          0
# Sex           0
# Cases         0
# Population    0
# Rate          0
# dtype: int64

# %%
mer.duplicated().sum()
# Out:
# 61248

# %%
mer.isna().sum()
# Out:
# County                             0
# Year                               0
# Population                         0
# Males                              0
# Females                            0
#                                   ..
# Hispanic-Native Mixed Females      0
# Hispanic-Asian Mixed Males         0
# Hispanic-Asian Mixed Females       0
# Hispanic-Hawaiian Mixed Males      0
# Hispanic-Hawaiian Mixed Females    0
# Length: 75, dtype: int64

# %% [markdown]
# We don't have any duplicates or null values in either of our datasets. That makes our job way easier. Now we can focus on the other parts of EDA

# %%
# Using T to transpose to make the original columns and rows switch, then reapplying .duplicated()
raw_inf.T.duplicated()
# Out:
# Disease       False
# County        False
# Year          False
# Sex           False
# Cases         False
# Population    False
# Rate          False
# dtype: bool

# %%
mer.T.duplicated()
# Out:
# County                             False
# Year                               False
# Population                         False
# Males                              False
# Females                            False
#                                    ...
# Hispanic-Native Mixed Females      False
# Hispanic-Asian Mixed Males         False
# Hispanic-Asian Mixed Females       False
# Hispanic-Hawaiian Mixed Males      False
# Hispanic-Hawaiian Mixed Females    False
# Length: 75, dtype: bool

# %% [markdown]
# Again, there are duplicated present in either dataset.

# %%
raw_inf.isna().sum(axis=0)
# Out:
# Disease       0
# County        0
# Year          0
# Sex           0
# Cases         0
# Population    0
# Rate          0
# dtype: int64

# %%
mer.isna().sum(axis=0)
# Out:
# County                             0
# Year                               0
# Population                         0
# Males                              0
# Females                            0
#                                   ..
# Hispanic-Native Mixed Females      0
# Hispanic-Asian Mixed Males         0
# Hispanic-Asian Mixed Females       0
# Hispanic-Hawaiian Mixed Males      0
# Hispanic-Hawaiian Mixed Females    0
# Length: 75, dtype: int64

# %%
mer.describe()
# Out:
#               Year    Population         Males       Females   White Males  \
# count  62524.00000  6.252400e+04  6.252400e+04  6.252400e+04  6.252400e+04
# mean    2011.50000  6.467946e+05  3.224646e+05  3.243301e+05  2.416891e+05
# std        6.34434  1.416602e+06  7.019549e+05  7.147048e+05  5.158111e+05
# min     2001.00000  1.042000e+03  5.520000e+02  4.820000e+02  3.730000e+02
# 25%     2006.00000  4.543750e+04  2.275075e+04  2.272725e+04  2.083225e+04
# 50%     2011.50000  1.798945e+05  9.000750e+04  9.075600e+04  7.847150e+04
# 75%     2017.00000  6.875930e+05  3.423612e+05  3.370392e+05  2.308010e+05
# max     2022.00000  1.010571e+07  4.980981e+06  5.125335e+06  3.660384e+06
#
#        White Females    Black Males  Black Females  Native Males  \
# count   6.252400e+04   62524.000000   62524.000000  62524.000000
# mean    2.390493e+05   21143.731191   21637.058777   4865.760188
# std     5.117573e+05   60197.115094   66947.154083   9550.713666
# min     3.180000e+02       0.000000       0.000000     27.000000
# 25%     2.086925e+04     438.750000     196.750000    676.000000
# 50%     8.050250e+04    2310.000000    1651.500000   1940.000000
# 75%     2.219042e+05   11322.250000   11079.750000   4879.500000
# max     3.617533e+06  456322.000000  520700.000000  75913.000000
#
#        Native Females  ...  Hispanic-White Mixed Males  \
# count    62524.000000  ...                6.252400e+04
# mean      4697.060345  ...                1.147597e+05
# std       9144.823030  ...                3.067983e+05
# min         23.000000  ...                2.900000e+01
# 25%        608.500000  ...                4.203250e+03
# 50%       1932.500000  ...                2.197600e+04
# 75%       4664.750000  ...                1.063122e+05
# max      71690.000000  ...                2.288151e+06
#
#        Hispanic-White Mixed Females  Hispanic-Black Mixed Males  \
# count                  6.252400e+04                62524.000000
# mean                   1.112514e+05                 3088.554075
# std                    3.041112e+05                 7940.348407
# min                    1.800000e+01                    1.000000
# 25%                    3.708250e+03                   83.750000
# 50%                    1.982250e+04                  438.000000
# 75%                    9.881450e+04                 2686.250000
# max                    2.300374e+06                68266.000000
#
#        Hispanic-Black Mixed Females  Hispanic-Native Mixed Males  \
# count                   62524.00000                 62524.000000
# mean                     3192.87931                  4694.674765
# std                      8295.09291                 10494.489131
# min                         0.00000                     6.000000
# 25%                        66.75000                   336.750000
# 50%                       469.00000                  1252.500000
# 75%                      2750.50000                  4518.250000
# max                     70097.00000                 89013.000000
#
#        Hispanic-Native Mixed Females  Hispanic-Asian Mixed Males  \
# count                   62524.000000                62524.000000
# mean                     4496.130094                 2674.873041
# std                     10050.415631                 6130.827263
# min                         4.000000                    0.000000
# 25%                       295.000000                   64.750000
# 50%                      1207.500000                  443.500000
# 75%                      4178.250000                 2655.250000
# max                     84397.000000                52481.000000
#
#        Hispanic-Asian Mixed Females  Hispanic-Hawaiian Mixed Males  \
# count                  62524.000000                   62524.000000
# mean                    2717.501567                     656.739028
# std                     6210.075293                    1449.767961
# min                        0.000000                       0.000000
# 25%                       48.000000                      25.000000
# 50%                      445.500000                     132.500000
# 75%                     2694.500000                     631.500000
# max                    52123.000000                   11791.000000
#
#        Hispanic-Hawaiian Mixed Females
# count                     62524.000000
# mean                        652.618339
# std                        1458.179029
# min                           0.000000
# 25%                          22.000000
# 50%                         124.500000
# 75%                         610.500000
# max                       11686.000000
#
# [8 rows x 74 columns]

# %%
raw_inf.describe()
# Out:
#                 Year          Cases    Population
# count  189921.000000  189921.000000  1.899210e+05
# mean     2011.803355      10.690319  8.533487e+05
# std         6.350271     146.497169  3.544983e+06
# min      2001.000000       0.000000  5.480000e+02
# 25%      2006.000000       0.000000  2.938700e+04
# 50%      2012.000000       0.000000  1.255400e+05
# 75%      2017.000000       0.000000  4.246320e+05
# max      2022.000000   10016.000000  3.952957e+07

# %%
raw_inf.select_dtypes(['object', 'int']).columns
# Out:
# Index(['Disease', 'County', 'Year', 'Sex', 'Cases', 'Population', 'Rate'], dtype='object')

# %%
mer.select_dtypes(['object', 'int']).columns
# Out:
# Index(['County', 'Year', 'Population', 'Males', 'Females', 'White Males',
#        'White Females', 'Black Males', 'Black Females', 'Native Males',
#        'Native Females', 'Asian Males', 'Asian Females', 'Hawaiian Male',
#        'Hawaiian Females', 'Multi-Race Males', 'Multi-Race Females',
#        'White-Mixed Males', 'White-Mixed Females', 'Black-Mixed Males',
#        'Black-Mixed Females', 'Native-Mixed Males', 'Native-Mixed Females',
#        'Asian-Mixed Males', 'Asian-Mixed Females', 'Hawaiian-Mixed Males',
#        'Hawaiian-Mixed Females', 'Not-Hispanic Males', 'Not-Hispanic Females',
#        'Not-Hispanic White Males', 'Not-Hispanic White Females',
#        'Not-Hispanic Black Males', 'Not-Hispanic Black Males.1',
#        'Not-Hispanic Native Male', 'Not-Hispanic Native Female',
#        'Not-Hispanic Asian Male', 'Not-Hispanic Asian Female',
#        'Not-Hispanic Hawaiian Male', 'Not-Hispanic Hawaiian Female',
#        'Not_Hispanic Mixed Males', 'Not_Hispanic Mixed Females',
#        ' Not_Hispanic White-Mixed Males', ' Not_Hispanic White-Mixed Females',
#        ' Not_Hispanic Black-Mixed Males', ' Not_Hispanic Black-Mixed Males.1',
#        ' Not_Hispanic Native-Mixed Males',
#        ' Not_Hispanic Native-Mixed Females', ' Not_Hispanic Asian-Mixed Males',
#        ' Not_Hispanic Asian-Mixed Females',
#        ' Not_Hispanic Hawaiian-Mixed Males',
#        ' Not_Hispanic Hawaiian-Mixed Females', 'Hispanic Males',
#        'Hispanic Females', 'Hispanic-White Males', 'Hispanic-White Females',
#        'Hispanic-Black Males', 'Hispanic-Black Females',
#        'Hispanic-Native Males', 'Hispanic-Native Females',
#        'Hispanic-Asian Males', 'Hispanic-Asian Females',
#        'Hispanic-Hawaiian Males', 'Hispanic-Hawaiian Females',
#        'Hispanic-Mixed Males', 'Hispanic-Mixed Females',
#        'Hispanic-White Mixed Males', 'Hispanic-White Mixed Females',
#        'Hispanic-Black Mixed Males', 'Hispanic-Black Mixed Females',
#        'Hispanic-Native Mixed Males', 'Hispanic-Native Mixed Females',
#        'Hispanic-Asian Mixed Males', 'Hispanic-Asian Mixed Females',
#        'Hispanic-Hawaiian Mixed Males', 'Hispanic-Hawaiian Mixed Females'],
#       dtype='object')

# %% [markdown]
# #### `Clean_inf` is the newest version of `inf`. In this dataframe, I have dropped `Sex` and `Population` so that I can use the same values from mer instead. This way it will be easier to merge both CSVs as there won't be conflicting values. In dropping the other categories, the shape of the df is now (63307, 5) which is a drastic change from the (189921, 7) it previously was.

# %%
clean_inf = pd.read_csv('new_inf.csv')

# %%
clean_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50044 entries, 0 to 50043
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   County   50044 non-null  object
#  1   Year     50044 non-null  int64
#  2   Disease  50044 non-null  object
#  3   Cases    50044 non-null  int64
#  4   Rate     50044 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.9+ MB

# %%
clean_inf.shape
# Out:
# (50044, 5)

# %%
clean_inf.duplicated().sum()
# Out:
# 0

# %%
clean_inf.isna().sum(axis = 0)
# Out:
# County     0
# Year       0
# Disease    0
# Cases      0
# Rate       0
# dtype: int64

# %%
clean_inf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50044 entries, 0 to 50043
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   County   50044 non-null  object
#  1   Year     50044 non-null  int64
#  2   Disease  50044 non-null  object
#  3   Cases    50044 non-null  int64
#  4   Rate     50044 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 1.9+ MB

# %%
mer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62524 entries, 0 to 62523
# Data columns (total 75 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   County                                62524 non-null  object
#  1   Year                                  62524 non-null  int64
#  2   Population                            62524 non-null  int64
#  3   Males                                 62524 non-null  int64
#  4   Females                               62524 non-null  int64
#  5   White Males                           62524 non-null  int64
#  6   White Females                         62524 non-null  int64
#  7   Black Males                           62524 non-null  int64
#  8   Black Females                         62524 non-null  int64
#  9   Native Males                          62524 non-null  int64
#  10  Native Females                        62524 non-null  int64
#  11  Asian Males                           62524 non-null  int64
#  12  Asian Females                         62524 non-null  int64
#  13  Hawaiian Male                         62524 non-null  int64
#  14  Hawaiian Females                      62524 non-null  int64
#  15  Multi-Race Males                      62524 non-null  int64
#  16  Multi-Race Females                    62524 non-null  int64
#  17  White-Mixed Males                     62524 non-null  int64
#  18  White-Mixed Females                   62524 non-null  int64
#  19  Black-Mixed Males                     62524 non-null  int64
#  20  Black-Mixed Females                   62524 non-null  int64
#  21  Native-Mixed Males                    62524 non-null  int64
#  22  Native-Mixed Females                  62524 non-null  int64
#  23  Asian-Mixed Males                     62524 non-null  int64
#  24  Asian-Mixed Females                   62524 non-null  int64
#  25  Hawaiian-Mixed Males                  62524 non-null  int64
#  26  Hawaiian-Mixed Females                62524 non-null  int64
#  27  Not-Hispanic Males                    62524 non-null  int64
#  28  Not-Hispanic Females                  62524 non-null  int64
#  29  Not-Hispanic White Males              62524 non-null  int64
#  30  Not-Hispanic White Females            62524 non-null  int64
#  31  Not-Hispanic Black Males              62524 non-null  int64
#  32  Not-Hispanic Black Males.1            62524 non-null  int64
#  33  Not-Hispanic Native Male              62524 non-null  int64
#  34  Not-Hispanic Native Female            62524 non-null  int64
#  35  Not-Hispanic Asian Male               62524 non-null  int64
#  36  Not-Hispanic Asian Female             62524 non-null  int64
#  37  Not-Hispanic Hawaiian Male            62524 non-null  int64
#  38  Not-Hispanic Hawaiian Female          62524 non-null  int64
#  39  Not_Hispanic Mixed Males              62524 non-null  int64
#  40  Not_Hispanic Mixed Females            62524 non-null  int64
#  41   Not_Hispanic White-Mixed Males       62524 non-null  int64
#  42   Not_Hispanic White-Mixed Females     62524 non-null  int64
#  43   Not_Hispanic Black-Mixed Males       62524 non-null  int64
#  44   Not_Hispanic Black-Mixed Males.1     62524 non-null  int64
#  45   Not_Hispanic Native-Mixed Males      62524 non-null  int64
#  46   Not_Hispanic Native-Mixed Females    62524 non-null  int64
#  47   Not_Hispanic Asian-Mixed Males       62524 non-null  int64
#  48   Not_Hispanic Asian-Mixed Females     62524 non-null  int64
#  49   Not_Hispanic Hawaiian-Mixed Males    62524 non-null  int64
#  50   Not_Hispanic Hawaiian-Mixed Females  62524 non-null  int64
#  51  Hispanic Males                        62524 non-null  int64
#  52  Hispanic Females                      62524 non-null  int64
#  53  Hispanic-White Males                  62524 non-null  int64
#  54  Hispanic-White Females                62524 non-null  int64
#  55  Hispanic-Black Males                  62524 non-null  int64
#  56  Hispanic-Black Females                62524 non-null  int64
#  57  Hispanic-Native Males                 62524 non-null  int64
#  58  Hispanic-Native Females               62524 non-null  int64
#  59  Hispanic-Asian Males                  62524 non-null  int64
#  60  Hispanic-Asian Females                62524 non-null  int64
#  61  Hispanic-Hawaiian Males               62524 non-null  int64
#  62  Hispanic-Hawaiian Females             62524 non-null  int64
#  63  Hispanic-Mixed Males                  62524 non-null  int64
#  64  Hispanic-Mixed Females                62524 non-null  int64
#  65  Hispanic-White Mixed Males            62524 non-null  int64
#  66  Hispanic-White Mixed Females          62524 non-null  int64
#  67  Hispanic-Black Mixed Males            62524 non-null  int64
#  68  Hispanic-Black Mixed Females          62524 non-null  int64
#  69  Hispanic-Native Mixed Males           62524 non-null  int64
#  70  Hispanic-Native Mixed Females         62524 non-null  int64
#  71  Hispanic-Asian Mixed Males            62524 non-null  int64
#  72  Hispanic-Asian Mixed Females          62524 non-null  int64
#  73  Hispanic-Hawaiian Mixed Males         62524 non-null  int64
#  74  Hispanic-Hawaiian Mixed Females       62524 non-null  int64
# dtypes: int64(74), object(1)
# memory usage: 35.8+ MB

# %% [markdown]
# ## Part 3
# Observations and Data Preprocessing of both CSVs combined.

# %% [markdown]
# #### `Final` is the latest version as it combines both the `Infectious` and `Merged` tables. I took the `Clean_inf` table from above and joined it to the demographics dataset. The final shape is (62234, 78). The good thing is I won't need to drop any additional fields as there are no null values or duplicates.

# %%
Final = pd.read_csv('final_merge.csv')
Final
# Out:
#                     Disease   County  Year  Cases Rate    Total   Males  \
# 0              Anaplasmosis  Alameda  2001      0    -  1468652  723957
# 1              Anaplasmosis  Alameda  2002      0    -  1460438  720008
# 2              Anaplasmosis  Alameda  2003      0    -  1451418  715373
# 3              Anaplasmosis  Alameda  2004      0    -  1441496  710595
# 4              Anaplasmosis  Alameda  2005      0    -  1435870  708070
# ...                     ...      ...   ...    ...  ...      ...     ...
# 62229  Zika Virus Infection     Yuba  2018      0    -    77557   39249
# 62230  Zika Virus Infection     Yuba  2019      0    -    78668   39819
# 62231  Zika Virus Infection     Yuba  2020      0    -    81994   42004
# 62232  Zika Virus Infection     Yuba  2021      0    -    83216   42550
# 62233  Zika Virus Infection     Yuba  2022      0    -    84310   43017
#
#        Females  White Males  White Females  ...  Hispanic-White Mixed Males  \
# 0       744695       430526         426851  ...                      137800
# 1       740430       426013         422003  ...                      139729
# 2       736045       421147         417397  ...                      140761
# 3       730901       416592         412797  ...                      141652
# 4       727800       413816         409781  ...                      143345
# ...        ...          ...            ...  ...                         ...
# 62229    38308        30806          30125  ...                       10162
# 62230    38849        31245          30419  ...                       10462
# 62231    39990        32575          31007  ...                       11102
# 62232    40666        32760          31234  ...                       11487
# 62233    41293        32745          31381  ...                       11981
#
#        Hispanic-White Mixed Females  Hispanic-Black Mixed Males  \
# 0                            125878                        5423
# 1                            127753                        5400
# 2                            128789                        5389
# 3                            130010                        5360
# 4                            131666                        5386
# ...                             ...                         ...
# 62229                          9668                         486
# 62230                         10024                         493
# 62231                         10410                         574
# 62232                         10788                         576
# 62233                         11247                         617
#
#        Hispanic-Black Mixed Females  Hispanic-Native Mixed Males  \
# 0                              5630                         4401
# 1                              5632                         4448
# 2                              5664                         4457
# 3                              5661                         4469
# 4                              5651                         4429
# ...                             ...                          ...
# 62229                           469                          949
# 62230                           481                          951
# 62231                           563                         1035
# 62232                           586                         1088
# 62233                           591                         1149
#
#        Hispanic-Native Mixed Females  Hispanic-Asian Mixed Males  \
# 0                               4138                        3883
# 1                               4162                        3955
# 2                               4131                        3984
# 3                               4146                        4017
# 4                               4150                        4109
# ...                              ...                         ...
# 62229                            982                         399
# 62230                            973                         407
# 62231                           1006                         479
# 62232                           1053                         512
# 62233                           1070                         558
#
#        Hispanic-Asian Mixed Females  Hispanic-Hawaiian Mixed Males  \
# 0                              4150                           1186
# 1                              4210                           1214
# 2                              4186                           1257
# 3                              4238                           1253
# 4                              4305                           1272
# ...                             ...                            ...
# 62229                           404                            103
# 62230                           405                            117
# 62231                           480                            150
# 62232                           509                            158
# 62233                           529                            178
#
#        Hispanic-Hawaiian Mixed Females
# 0                                 1254
# 1                                 1250
# 2                                 1241
# 3                                 1277
# 4                                 1284
# ...                                ...
# 62229                               88
# 62230                              113
# 62231                              134
# 62232                              135
# 62233                              141
#
# [62234 rows x 78 columns]

# %%
Final.shape
# Out:
# (62234, 78)

# %%
Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62234 entries, 0 to 62233
# Data columns (total 78 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Disease                               62234 non-null  object
#  1   County                                62234 non-null  object
#  2   Year                                  62234 non-null  int64
#  3   Cases                                 62234 non-null  int64
#  4   Rate                                  62234 non-null  object
#  5   Total                                 62234 non-null  int64
#  6   Males                                 62234 non-null  int64
#  7   Females                               62234 non-null  int64
#  8   White Males                           62234 non-null  int64
#  9   White Females                         62234 non-null  int64
#  10  Black Males                           62234 non-null  int64
#  11  Black Females                         62234 non-null  int64
#  12  Native Males                          62234 non-null  int64
#  13  Native Females                        62234 non-null  int64
#  14  Asian Males                           62234 non-null  int64
#  15  Asian Females                         62234 non-null  int64
#  16  Hawaiian Male                         62234 non-null  int64
#  17  Hawaiian Females                      62234 non-null  int64
#  18  Multi-Race Males                      62234 non-null  int64
#  19  Multi-Race Females                    62234 non-null  int64
#  20  White-Mixed Males                     62234 non-null  int64
#  21  White-Mixed Females                   62234 non-null  int64
#  22  Black-Mixed Males                     62234 non-null  int64
#  23  Black-Mixed Females                   62234 non-null  int64
#  24  Native-Mixed Males                    62234 non-null  int64
#  25  Native-Mixed Females                  62234 non-null  int64
#  26  Asian-Mixed Males                     62234 non-null  int64
#  27  Asian-Mixed Females                   62234 non-null  int64
#  28  Hawaiian-Mixed Males                  62234 non-null  int64
#  29  Hawaiian-Mixed Females                62234 non-null  int64
#  30  Not-Hispanic Males                    62234 non-null  int64
#  31  Not-Hispanic Females                  62234 non-null  int64
#  32  Not-Hispanic White Males              62234 non-null  int64
#  33  Not-Hispanic White Females            62234 non-null  int64
#  34  Not-Hispanic Black Males              62234 non-null  int64
#  35  Not-Hispanic Black Males.1            62234 non-null  int64
#  36  Not-Hispanic Native Male              62234 non-null  int64
#  37  Not-Hispanic Native Female            62234 non-null  int64
#  38  Not-Hispanic Asian Male               62234 non-null  int64
#  39  Not-Hispanic Asian Female             62234 non-null  int64
#  40  Not-Hispanic Hawaiian Male            62234 non-null  int64
#  41  Not-Hispanic Hawaiian Female          62234 non-null  int64
#  42  Not_Hispanic Mixed Males              62234 non-null  int64
#  43  Not_Hispanic Mixed Females            62234 non-null  int64
#  44   Not_Hispanic White-Mixed Males       62234 non-null  int64
#  45   Not_Hispanic White-Mixed Females     62234 non-null  int64
#  46   Not_Hispanic Black-Mixed Males       62234 non-null  int64
#  47   Not_Hispanic Black-Mixed Males.1     62234 non-null  int64
#  48   Not_Hispanic Native-Mixed Males      62234 non-null  int64
#  49   Not_Hispanic Native-Mixed Females    62234 non-null  int64
#  50   Not_Hispanic Asian-Mixed Males       62234 non-null  int64
#  51   Not_Hispanic Asian-Mixed Females     62234 non-null  int64
#  52   Not_Hispanic Hawaiian-Mixed Males    62234 non-null  int64
#  53   Not_Hispanic Hawaiian-Mixed Females  62234 non-null  int64
#  54  Hispanic Males                        62234 non-null  int64
#  55  Hispanic Females                      62234 non-null  int64
#  56  Hispanic-White Males                  62234 non-null  int64
#  57  Hispanic-White Females                62234 non-null  int64
#  58  Hispanic-Black Males                  62234 non-null  int64
#  59  Hispanic-Black Females                62234 non-null  int64
#  60  Hispanic-Native Males                 62234 non-null  int64
#  61  Hispanic-Native Females               62234 non-null  int64
#  62  Hispanic-Asian Males                  62234 non-null  int64
#  63  Hispanic-Asian Females                62234 non-null  int64
#  64  Hispanic-Hawaiian Males               62234 non-null  int64
#  65  Hispanic-Hawaiian Females             62234 non-null  int64
#  66  Hispanic-Mixed Males                  62234 non-null  int64
#  67  Hispanic-Mixed Females                62234 non-null  int64
#  68  Hispanic-White Mixed Males            62234 non-null  int64
#  69  Hispanic-White Mixed Females          62234 non-null  int64
#  70  Hispanic-Black Mixed Males            62234 non-null  int64
#  71  Hispanic-Black Mixed Females          62234 non-null  int64
#  72  Hispanic-Native Mixed Males           62234 non-null  int64
#  73  Hispanic-Native Mixed Females         62234 non-null  int64
#  74  Hispanic-Asian Mixed Males            62234 non-null  int64
#  75  Hispanic-Asian Mixed Females          62234 non-null  int64
#  76  Hispanic-Hawaiian Mixed Males         62234 non-null  int64
#  77  Hispanic-Hawaiian Mixed Females       62234 non-null  int64
# dtypes: int64(75), object(3)
# memory usage: 37.0+ MB

# %%
Final.duplicated().sum()
# Out:
# 0

# %%
Final.T.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### The table below shows all the elements in the dataset. Keep in mind that the datatypes are dynamic and most likely will change throughout the process.

# %% [markdown]
# | Column Name                         | Data Type |
# |-------------------------------------|-----------|
# | Disease                             | Object    |
# | County                              | Object    |
# | Year                                | Int64     |
# | Cases                               | Int64     |
# | Rate                                | Object    |
# | Total                               | Int64     |
# | Males                               | Int64     |
# | Females                             | Int64     |
# | White Males                         | Int64     |
# | White Females                       | Int64     |
# | Black Males                         | Int64     |
# | Black Females                       | Int64     |
# | Native Males                        | Int64     |
# | Native Females                      | Int64     |
# | Asian Males                         | Int64     |
# | Asian Females                       | Int64     |
# | Hawaiian Male                       | Int64     |
# | Hawaiian Females                    | Int64     |
# | Multi-Race Males                    | Int64     |
# | Multi-Race Females                  | Int64     |
# | White-Mixed Males                   | Int64     |
# | White-Mixed Females                 | Int64     |
# | Black-Mixed Males                   | Int64     |
# | Black-Mixed Females                 | Int64     |
# | Native-Mixed Males                  | Int64     |
# | Native-Mixed Females                | Int64     |
# | Asian-Mixed Males                   | Int64     |
# | Asian-Mixed Females                 | Int64     |
# | Hawaiian-Mixed Males                | Int64     |
# | Hawaiian-Mixed Females              | Int64     |
# | Not-Hispanic Males                  | Int64     |
# | Not-Hispanic Females                | Int64     |
# | Not-Hispanic White Males            | Int64     |
# | Not-Hispanic White Females          | Int64     |
# | Not-Hispanic Black Males            | Int64     |
# | Not-Hispanic Black Males.1          | Int64     |
# | Not-Hispanic Native Male            | Int64     |
# | Not-Hispanic Native Female          | Int64     |
# | Not-Hispanic Asian Male             | Int64     |
# | Not-Hispanic Asian Female           | Int64     |
# | Not-Hispanic Hawaiian Male          | Int64     |
# | Not-Hispanic Hawaiian Female        | Int64     |
# | Not_Hispanic Mixed Males            | Int64     |
# | Not_Hispanic Mixed Females          | Int64     |
# | Not_Hispanic White-Mixed Males      | Int64     |
# | Not_Hispanic White-Mixed Females    | Int64     |
# | Not_Hispanic Black-Mixed Males      | Int64     |
# | Not_Hispanic Black-Mixed Males.1    | Int64     |
# | Not_Hispanic Native-Mixed Males     | Int64     |
# | Not_Hispanic Native-Mixed Females   | Int64     |
# | Not_Hispanic Asian-Mixed Males      | Int64     |
# | Not_Hispanic Asian-Mixed Females    | Int64     |
# | Not_Hispanic Hawaiian-Mixed Males   | Int64     |
# | Not_Hispanic Hawaiian-Mixed Females | Int64     |
# | Hispanic Males                      | Int64     |
# | Hispanic Females                    | Int64     |
# | Hispanic-White Males                | Int64     |
# | Hispanic-White Females              | Int64     |
# | Hispanic-Black Males                | Int64     |
# | Hispanic-Black Females              | Int64     |
# | Hispanic-Native Males               | Int64     |
# | Hispanic-Native Females             | Int64     |
# | Hispanic-Asian Males                | Int64     |
# | Hispanic-Asian Females              | Int64     |
# | Hispanic-Hawaiian Males             | Int64     |
# | Hispanic-Hawaiian Females           | Int64     |
# | Hispanic-Mixed Males                | Int64     |
# | Hispanic-Mixed Females              | Int64     |
# | Hispanic-White Mixed Males          | Int64     |
# | Hispanic-White Mixed Females        | Int64     |
# | Hispanic-Black Mixed Males          | Int64     |
# | Hispanic-Black Mixed Females        | Int64     |
# | Hispanic-Native Mixed Males         | Int64     |
# | Hispanic-Native Mixed Females       | Int64     |
# | Hispanic-Asian Mixed Males          | Int64     |
# | Hispanic-Asian Mixed Females        | Int64     |
# | Hispanic-Hawaiian Mixed Males       | Int64     |
# | Hispanic-Hawaiian Mixed Females     | Int64     |

# %%
Final.isna().sum(axis = 0)
# Out:
# Disease                            0
# County                             0
# Year                               0
# Cases                              0
# Rate                               0
#                                   ..
# Hispanic-Native Mixed Females      0
# Hispanic-Asian Mixed Males         0
# Hispanic-Asian Mixed Females       0
# Hispanic-Hawaiian Mixed Males      0
# Hispanic-Hawaiian Mixed Females    0
# Length: 78, dtype: int64

# %% [markdown]
# Overall, the data is pretty clean and seems easy to work with. I'll play around with it more and see if I can plot anything interesting.
